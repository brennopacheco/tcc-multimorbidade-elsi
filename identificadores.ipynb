# %%
# Lista final de identificadores baseada nas suas tabelas de Preditoras e Desfechos
# Regra: 1 identificador por variável (com exceção dos pares necessários para cálculo de IMC e RCQ)

identificadores = [
    # --- PREDITORAS ---

    # 1. Sociodemográficas
    "sexo",    # Sexo
    "idade",   # Idade
    "e22",     # Escolaridade
    "e9",      # Raça/Cor
    "e7",      # Estado Civil
    "e11",     # Filhos
    "e17",     # Escolaridade Materna
    " d28",    # Renda Domiciliar

    # 2. Estilo de Vida
    # "n1",      # Auto Avaliação
    "l30",     # Tabagismo (Fuma atualmente)
    "l24",     # Álcool (Frequência)
    "l1",      # Atividade Física (Vigorosa - 1º do bloco)
    "l5",      # Dias de Ativ. Física (Caminhada - 1º do bloco)
    "n74",     # Qualidade do Sono
    "n74_1",   # Problema para dormir
    "l19",     # Consumo de Frutas (Dias)
    "l15",     # Consumo de Vegetais (Dias)
    # "o1",      # Saúde Bucal

    # 3. Antropométricas (Necessários pares para cálculo)
    "mf22",    # Peso (para IMC)
    "mf13",    # Altura (para IMC)
    "mf9",     # Pressão Arterial Sistólica (Média)
    "mf10",    # Pressão Arterial Diastólica (Média)
    "mf10_1",  # Frequência Cardíaca
    "mf17m",   # Cintura (para Relação C/Q)
    "mf19m",   # Quadril (para Relação C/Q)

    # --- DESFECHOS (DOENÇAS) ---

    "n28",     # Hipertensão
    "n35",     # Diabetes
    "n44",     # Colesterol
    "n46",     # Infarto
    "n48",     # Angina (Componente 1 de Doença Cardíaca)
    "n50",     # Insuficiência Cardíaca (Componente 2 de Doença Cardíaca)
    "n52",     # AVC
    "n66",     # Angioplastia e Stent
    "n54",     # Asma
    "n60",     # Câncer

    # --- DOENÇAS EXTRAS (SUGERIDAS) ---
    "n61",     # Insuficiência Renal
    "n55",     # DPOC
    "n56",     # Artrite
    "n59",     # Depressão
    "n62",     # Parkinson
    "n63"      # Alzheimer
]

# Gerar o arquivo .txt
nome_arquivo = "variaveis_elsi.txt"

with open(nome_arquivo, "w") as arquivo:
    for variavel in identificadores:
        arquivo.write(f"{variavel}\n")

print(f"Arquivo '{nome_arquivo}' gerado com sucesso com {len(identificadores)} identificadores.")
# Out:
# Arquivo 'variaveis_elsi.txt' gerado com sucesso com 38 identificadores.
